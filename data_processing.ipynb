# %% [markdown]
# # Data Preprocessing and NLP Analysis

# %%
# Importing the Raw Data

import duckdb

con = duckdb.connect("madoc.db")

con.execute("""
CREATE TABLE madoc AS
SELECT 
    *,
    split_part(filename, '_', 1) AS platform,
    split_part(filename, '_', 2) AS community
FROM read_parquet('D:/Varun Kumar/Proejekt/Data/raw/*.parquet', filename=true);
""")

# %%
# Converting date column type

con.execute("""
ALTER TABLE madoc ADD COLUMN publish_ts TIMESTAMP;
""")

con.execute("""
UPDATE madoc 
SET publish_ts = to_timestamp(publish_date);
""")

con.execute("""
ALTER TABLE madoc ADD COLUMN year INTEGER;
""")

con.execute("""
UPDATE madoc 
SET year = EXTRACT(year FROM publish_ts);
""")

# %%
df = con.execute(
    """SELECT * FROM madoc"""
)

# %%
# Dropping unused/unnecessary columns

con.execute("""
ALTER TABLE madoc
DROP COLUMN filename;
""")

con.execute("""
ALTER TABLE madoc
DROP COLUMN platform_1;
""")

con.execute("""
ALTER TABLE madoc
DROP COLUMN community_1;
""")

con.execute("""
ALTER TABLE madoc
DROP COLUMN strict_filter;
""")

# %%
con.table("madoc").show()
# Out:
# ┌──────────────────────────────────────┬──────────────┬──────────────────────────────────────┬──────────────────────────────────────┬──────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────┬──────────────────┬──────────┬───────────────┬─────────────────┬─────────────────────┬───────┐
# │               post_id                │ publish_date │               user_id                │              parent_id               │            parent_user_id            │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 content                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │                                                   url                                                    │ language │ interaction_type │ platform │   community   │ sentiment_vader │     publish_ts      │ year  │
# │               varchar                │    int64     │               varchar                │               varchar                │               varchar                │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 varchar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │                                                 varchar                                                  │ varchar  │     varchar      │ varchar  │    varchar    │     double      │      timestamp      │ int32 │
# ├──────────────────────────────────────┼──────────────┼──────────────────────────────────────┼──────────────────────────────────────┼──────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────┼──────────────────┼──────────┼───────────────┼─────────────────┼─────────────────────┼───────┤
# │ 8b9bc303-7770-5d73-a2c6-948471830dee │   1419283272 │ 3616d72b-c2a7-5bc5-be38-aec8a1df0159 │ NULL                                 │ NULL                                 │ First post ( ͡° ͜ʖ ͡°)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ https://www.youtube.com/watch?v=t5RLwgDCsm4                                                              │ English  │ POST             │ reddit   │ CringeAnarchy │             0.0 │ 2014-12-23 02:51:12 │  2014 │
# │ 9d730ec8-b236-5d71-9009-c279acae556a │   1419284471 │ 3616d72b-c2a7-5bc5-be38-aec8a1df0159 │ NULL                                 │ NULL                                 │ This subreddit was created today, and is currently under construction. In the meantime, feel free to beta-test the colored text fonts.----------------------\n\n**Font colors:**\n\n- `[Your Text here](#b0)` = **Your Text here**\n\n- `[Your Text here](#g0)` = [Your Text here](#g0)\n\n- `[Your Text here](#r0)` = [Your Text here](#r0)\n\n- `[Your Text here](#c0)` = [Your Text here](#c0)\n\n- `[Your Text here](#o0)` = [Your Text here](#o0)\n\n- `[Your Text here](#grey0)` = [Your Text here](#grey0)\n\n- `[Appears when upvoted](#gh0)` = [Appears when upvoted](#gh0)\n\n----------------------\n\n**Size Variations (Pattern applies to all colors):**\n\n- `[Your Text here](#g0)` = [Your Text here](#g0)\n\n- `[Your Text here](#g1)` = [Your Text here](#g1)\n\n- `[Your Text here](#g2)` = [Your Text here](#g2)\n\n- `[Your Text here](#g3)` = [Your Text here](#g3)\n\n----------------------\n\n**Other:**\n\n`Begin a line with ###### for the following effect:`\n\n######Fire text\n\n---------------------- │ http://www.reddit.com/r/CringeAnarchy/comments/2q3xhs/this_subreddit_was_created_today_and_is_currently/ │ English  │ POST             │ reddit   │ CringeAnarchy │          0.6486 │ 2014-12-23 03:11:11 │  2014 │
# │ 1e992558-022f-590d-a93d-5b2299c6b563 │   1419286027 │ 8266167b-90bd-5d66-b5c1-8af2d3948d48 │ NULL                                 │ NULL                                 │ Star Trek / Doctor Who Mashup...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ https://www.youtube.com/watch?v=uiyrIuotFFA                                                              │ English  │ POST             │ reddit   │ CringeAnarchy │             0.0 │ 2014-12-23 03:37:07 │  2014 │
# │ 9d1389b7-c9a4-5b70-b3a5-1abb121dee47 │   1419286582 │ 40bfefc1-0f61-54a2-8852-b859772c6ce2 │ NULL                                 │ NULL                                 │ Pornstar freaks out because of hippies                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ http://efukt.com/21055_The_Trainwreck_of_all_Trainwrecks.html                                            │ English  │ POST             │ reddit   │ CringeAnarchy │         -0.1027 │ 2014-12-23 03:46:22 │  2014 │
# │ cc979e6a-27ba-588d-93a7-337d31784d3b │   1419286821 │ 3506345b-51fb-5e0d-b8af-03f0c43756b9 │ NULL                                 │ NULL                                 │ "It's much easier for a woman to find a new man."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ https://www.youtube.com/watch?v=UReTtePcLlA                                                              │ English  │ POST             │ reddit   │ CringeAnarchy │          0.4215 │ 2014-12-23 03:50:21 │  2014 │
# │ da0fcd64-1f9d-589f-bc53-659a28bd1868 │   1419286920 │ 3506345b-51fb-5e0d-b8af-03f0c43756b9 │ 8b9bc303-7770-5d73-a2c6-948471830dee │ 3616d72b-c2a7-5bc5-be38-aec8a1df0159 │ This was so hard to watch. I'm so glad video cameras weren't abundant when I was a teen.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          0.4588 │ 2014-12-23 03:52:00 │  2014 │
# │ f416bf97-e1c8-53ce-8426-b8bb705b8af0 │   1419286929 │ 40bfefc1-0f61-54a2-8852-b859772c6ce2 │ NULL                                 │ NULL                                 │ Black Homophobic Christians at rally                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    │ https://www.youtube.com/watch?v=NGVRz3-FbU0                                                              │ English  │ POST             │ reddit   │ CringeAnarchy │             0.0 │ 2014-12-23 03:52:09 │  2014 │
# │ 23252ff1-8dd8-5f0c-b518-c4c18ecf6533 │   1419287378 │ 3616d72b-c2a7-5bc5-be38-aec8a1df0159 │ 9d730ec8-b236-5d71-9009-c279acae556a │ 3616d72b-c2a7-5bc5-be38-aec8a1df0159 │ [TEST POST PLEASE IGNORE (that means upvote)](#r2)\n\n[✓ Thanks!](#gh3)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          -0.126 │ 2014-12-23 03:59:38 │  2014 │
# │ 7cf31a96-6eea-55f3-8d28-4bf28051a380 │   1419288340 │ 055ba0aa-c66f-5f1f-a03d-c379c5c14dbf │ 9d730ec8-b236-5d71-9009-c279acae556a │ 3616d72b-c2a7-5bc5-be38-aec8a1df0159 │ [Hello?](#o0)\n\nOh I suppose I should allow subreddit styles...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          0.2263 │ 2014-12-23 04:15:40 │  2014 │
# │ c23b7c0e-70b5-50d6-a6bc-945ecc84eb41 │   1419288989 │ e330d209-8949-5b52-b6d3-17ac0bb77964 │ NULL                                 │ NULL                                 │ White Knights gottaa do what they gotta do...make us cringe.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │ https://www.youtube.com/watch?v=5ffZgq3yvB0                                                              │ English  │ POST             │ reddit   │ CringeAnarchy │             0.0 │ 2014-12-23 04:26:29 │  2014 │
# │                  ·                   │        ·     │                  ·                   │  ·                                   │  ·                                   │                              ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  ·                                                                                                       │    ·     │  ·               │   ·      │       ·       │              ·  │          ·          │    ·  │
# │                  ·                   │        ·     │                  ·                   │  ·                                   │  ·                                   │                              ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  ·                                                                                                       │    ·     │  ·               │   ·      │       ·       │              ·  │          ·          │    ·  │
# │                  ·                   │        ·     │                  ·                   │  ·                                   │  ·                                   │                              ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  ·                                                                                                       │    ·     │  ·               │   ·      │       ·       │              ·  │          ·          │    ·  │
# │ e5915ff9-23c6-55ae-a4d6-de9eb99aac58 │   1422897547 │ a8957c19-4dc0-5b39-877c-7914743e4c04 │ NULL                                 │ NULL                                 │ Strange, the only thing I can make out of that collection of letters is "I let my feelings get in the way of what I find funny".  I'll bet you like female comedians, too.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          0.4404 │ 2015-02-02 22:49:07 │  2015 │
# │ e9bd852a-e0c7-59ce-a390-71faaeec436a │   1422897633 │ 0dafbc09-f981-50da-953f-fd8016cafe33 │ NULL                                 │ NULL                                 │ I cant think of any,but than again I dont really like comedians apart from Jim Jefferies and Louis ck.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │           -0.53 │ 2015-02-02 22:50:33 │  2015 │
# │ 0e22fbb5-aa55-5962-a666-235871f69e39 │   1422898069 │ a064ecb9-8384-56fc-96d1-268ad98632b6 │ NULL                                 │ NULL                                 │ Do you feel the euphoria?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          0.6486 │ 2015-02-02 22:57:49 │  2015 │
# │ 58d13a07-6f7a-5251-a5a2-06b402b42061 │   1422898211 │ d81e3f0d-9f07-546e-a1c5-011b3647472e │ NULL                                 │ NULL                                 │ You have a mother joke in your post history. People have dead mothers. So harsh, bro.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │         -0.7425 │ 2015-02-02 23:00:11 │  2015 │
# │ 0ab4acd7-ee43-5a0c-ae2d-0f00bacc2210 │   1422898353 │ 0dafbc09-f981-50da-953f-fd8016cafe33 │ NULL                                 │ NULL                                 │ Do I say it to the guy's face?\nEdit: that was a joke,not an insult there is a huge difference,one of which is the joke was not directed at someone in particular unlike the insults in those comments                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │         -0.3818 │ 2015-02-02 23:02:33 │  2015 │
# │ ba11134d-f557-5db2-80ca-23d306a348d8 │   1422898438 │ a8957c19-4dc0-5b39-877c-7914743e4c04 │ NULL                                 │ NULL                                 │ So it's better to be a coward?  You have some fucked up ideas about reality.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │         -0.6395 │ 2015-02-02 23:03:58 │  2015 │
# │ b0e19a44-ee10-58b1-ab77-afb78ed5ac2c │   1422898478 │ 0dafbc09-f981-50da-953f-fd8016cafe33 │ NULL                                 │ NULL                                 │ Might want to re read the comment I did there bud                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          0.0772 │ 2015-02-02 23:04:38 │  2015 │
# │ 00c4f843-4925-58fe-bed5-ea93be381e5e │   1422898574 │ d81e3f0d-9f07-546e-a1c5-011b3647472e │ NULL                                 │ NULL                                 │ I don't remember saying it to his face... get a sense of humor, you little bitch.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │         -0.3415 │ 2015-02-02 23:06:14 │  2015 │
# │ 3f5715a6-0f52-55d0-b03c-084d02f575da │   1422898646 │ 2c60d4e6-ec29-5ded-8ba9-7da2ea49e44e │ NULL                                 │ NULL                                 │ &gt;Tips fedora.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ NULL                                                                                                     │ English  │ COMMENT          │ reddit   │ CringeAnarchy │             0.0 │ 2015-02-02 23:07:26 │  2015 │
# │ c952d07e-1cd5-5670-b4d7-0ebdc36940d7 │   1422898686 │ 0dafbc09-f981-50da-953f-fd8016cafe33 │ NULL                                 │ NULL                                 │ http://i.imgur.com/IICNLnI.png\nYeah,you did haha                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ http://i.imgur.com/IICNLnI.png                                                                           │ English  │ COMMENT          │ reddit   │ CringeAnarchy │          0.4588 │ 2015-02-02 23:08:06 │  2015 │
# ├──────────────────────────────────────┴──────────────┴──────────────────────────────────────┴──────────────────────────────────────┴──────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────┴──────────────────┴──────────┴───────────────┴─────────────────┴─────────────────────┴───────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               14 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
con.execute("DESCRIBE madoc").df()
# Out:
#          column_name column_type null   key default extra
# 0            post_id     VARCHAR  YES  None    None  None
# 1       publish_date      BIGINT  YES  None    None  None
# 2            user_id     VARCHAR  YES  None    None  None
# 3          parent_id     VARCHAR  YES  None    None  None
# 4     parent_user_id     VARCHAR  YES  None    None  None
# 5            content     VARCHAR  YES  None    None  None
# 6                url     VARCHAR  YES  None    None  None
# 7           language     VARCHAR  YES  None    None  None
# 8   interaction_type     VARCHAR  YES  None    None  None
# 9           platform     VARCHAR  YES  None    None  None
# 10         community     VARCHAR  YES  None    None  None
# 11   sentiment_vader      DOUBLE  YES  None    None  None
# 12        publish_ts   TIMESTAMP  YES  None    None  None
# 13              year     INTEGER  YES  None    None  None

# %%
con.execute("ALTER TABLE madoc DROP COLUMN publish_date;")

# %%
# Exporting the cleaned data

con.execute("""
COPY madoc TO 'madoc_all.parquet'
(FORMAT PARQUET, COMPRESSION ZSTD);
""")

# %%
con.execute("SELECT * FROM madoc WHERE platform = 'voat' AND content IS NOT NULL").df().shape
# Out:
# (714230, 13)

# %%
con.execute("SELECT COUNT(*) FROM madoc WHERE platform = 'reddit' AND content IS NOT NULL").df()
# Out:
#    count_star()
# 0      19960037

# %% [markdown]
# ### Why we create this 200k sample

# %% [markdown]
# The MADOC dataset contains ~20 million posts, but Reddit heavily dominates the data (≈20M vs ≈700k Voat). Running deep-learning models like DistilBERT on the full dataset is not feasible, and using the raw distribution would bias any model toward Reddit.
#
# To enable fair cross-platform NLP analysis, we create a balanced sample of 200,000 posts:
#
# 100,000 randomly sampled from Reddit
#
# 100,000 randomly sampled from Voat
#
# This sample is large enough to be statistically meaningful, small enough to process on a GPU, and balanced so that Reddit and Voat contribute equally. The full dataset remains in DuckDB for large-scale trend analysis, while this sample is used for expensive NLP tasks such as BERT sentiment and toxicity scoring.

# %%
con.execute("""
COPY (
    -- Wrap the filter in a subquery so sampling happens on the RESULT of the filter
    SELECT * FROM (
        SELECT * FROM madoc 
        WHERE platform = 'reddit' AND content IS NOT NULL
    ) USING SAMPLE reservoir(100000)

    UNION ALL

    SELECT * FROM (
        SELECT * FROM madoc 
        WHERE platform = 'voat' AND content IS NOT NULL
    ) USING SAMPLE reservoir(100000)
) TO 'ml_sample_200k.parquet'
(FORMAT PARQUET, COMPRESSION ZSTD);
""")

# %%
import pandas as pd

sample = pd.read_parquet("ml_sample_200k.parquet")
sample.shape
# Out:
# (200000, 13)

# %%
sample['platform'].value_counts()
# Out:
# platform
# reddit    100000
# voat      100000
# Name: count, dtype: int64
